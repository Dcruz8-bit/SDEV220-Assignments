# %%
# David Cruz Python Assignments Notebook

# Module 2 Chapter 3: Things to Do (3.1 to 3.6)

# 3.1 How many seconds are in an hour?
60 * 60

# 3.2 Assign the result to a variable
seconds_per_hour = 60 * 60
seconds_per_hour

# 3.3 How many seconds are in a day?
seconds_per_hour * 24

# 3.4 Save the result in a variable
seconds_per_day = seconds_per_hour * 24
seconds_per_day

# 3.5 Floating-point division
seconds_per_day / seconds_per_hour

# 3.6 Integer division
seconds_per_day // seconds_per_hour

# Yes, the result of the integer division in 3.6 matches the floating-point result in 3.5,
# except for the `.0` at the end. Both show that there are 24 hours in a day.


# Module 3 Conditionals (Assignments 4.1 & 4.2)

# Assignment 4.1
# This code compares a guessed number to a secret number and prints whether the guess is too low, too high, or just right.

secret = 7
guess = 4

if guess < secret:
    print('too low')
elif guess > secret:
    print('too high')
else:
    print('just right')

# Assignment 4.2
# This code uses boolean variables to determine which fruit or vegetable matches the traits "small" and "green".

small = True
green = True

if small and green:
    print('pea')
elif small and not green:
    print('cherry')
elif not small and green:
    print('watermelon')
else:
    print('pumpkin')


# Module 4 Loops (Assignments 6.1 to 6.3)

# Assignment 6.1
# This code uses a for loop to print the values in the list [3, 2, 1, 0].

for i in [3, 2, 1, 0]:
    print(i)

# Assignment 6.2
# This code uses a while loop to compare a number to guess_me and prints feedback until the correct value is found or exceeded.

guess_me = 7
number = 1

while True:
    if number < guess_me:
        print('too low')
    elif number == guess_me:
        print('found it!')
        break
    else:
        print('oops')
        break
    number += 1

# Assignment 6.3
# This code uses a for loop to compare numbers in a range to guess_me and prints feedback, breaking when the correct value is found or exceeded.

guess_me = 5

for number in range(10):
    if number < guess_me:
        print('too low')
    elif number == guess_me:
        print('found it!')
        break
    else:
        print('oops')
        break

# David Cruz Python Assignments Notebook
# Module 2 Chapter 3: Things to Do (3.1 to 3.6)

# 7.1 Create a list of years from birth year to fifth birthday
birth_year = 1998
years_list = [birth_year, birth_year+1, birth_year+2, birth_year+3, birth_year+4, birth_year+5]
print("Years List:", years_list)

# 7.2 Year of third birthday
third_birthday_year = years_list[3]   # index 3 because 0 = birth year
print("Third Birthday Year:", third_birthday_year)

# 7.3 Year when you were the oldest
oldest_year = years_list[-1]   # last element
print("Oldest Year:", oldest_year)

# 7.4 Create list of things
things = ["mozzarella", "cinderella", "salmonella"]
print("Things:", things)

# 7.5 Capitalize the person
things[1] = things[1].capitalize()
print("After Capitalizing Person:", things)

# 7.6 Uppercase the cheese
things[0] = things[0].upper()
print("After Uppercasing Cheese:", things)

# 7.7 Delete the disease
del things[2]
print("After Deleting Disease:", things)

# 7.8 Create surprise list
surprise = ["Groucho", "Chico", "Harpo"]
print("Surprise List:", surprise)

# 7.9 Lowercase last element, reverse it, capitalize
surprise[-1] = surprise[-1].lower()[::-1].capitalize()
print("After Transforming Last Element:", surprise)

# 7.10 List comprehension for even numbers
even = [num for num in range(10) if num % 2 == 0]
print("Even Numbers:", even)

# 7.11 Jump rope rhyme maker
start1 = ["fee", "fie", "foe"]
rhymes = [
    ("flop", "get a mop"),
    ("fope", "turn the rope"),
    ("fa", "get your ma"),
    ("fudge", "call the judge"),
    ("fat", "pet the cat"),
    ("fog", "walk the dog"),
    ("fun", "say we're done"),
]
start2 = "Someone better"

for first, second in rhymes:
    # First line
    for word in start1:
        print(word.capitalize() + "!", end=" ")
    print(first.capitalize() + "!")
    
    # Second line
    print(start2, second + ".")
